# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul94jh/MSC-Research/blob/main/CNN_simple_YouTube_clickbait_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.14.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.0 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.14.0

# %%
#! pip install tensorflow --upgrade

# %% [markdown]
# #Imports

# %%
import os, sys, math
import numpy as np
import random
import pandas as pd
from matplotlib import pyplot as plt


from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score



import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import tensorflow_addons as tfa   # for optimizer
import keras.backend as K
import tensorflow_hub as hub
from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import SGD

AUTO = tf.data.experimental.AUTOTUNE # used in tf.data.Dataset API

tf.get_logger().setLevel('ERROR')

import sys

#Import custom script
sys.path.append('/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/scripts')
from tf_dataset_helpers import read_tfrec_data
import model_helpers as mh
import visualization_helpers as vh
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# #Configurations

# %%
TARGET_SIZE = [180, 180]
CLASSES = ['nonclickbaits', 'clickbaits'] 
NUM_CLASSES = 2
BATCH_SIZE = 32  # On Colab/GPU, a higher batch size does not help and sometimes does not fit on the GPU (OOM)
WIDTH = 180
HEIGHT = 180
CHANNELS = 3
INPUT_SHAPE = (WIDTH, HEIGHT, CHANNELS)


label_list = [0,1]
init_lr = 1e-4
epochs=20

# %%
tfrec_trainVal_files_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/tfrec_data/train_val/'
tfrec_test_files_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/tfrec_data/test/'
fvc_clickbait_tfrecFiles_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/FVC_CORPUS/tfrec_data/'
tfrec_benchmark_files_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/invid_fake_video_v2/tfrec_data/'

model_root_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/models/image_models'
saved_model_name = f'youtube_clickbait_simple_CNN'
saved_model_path = os.path.join(model_root_path, saved_model_name )

checkpoint_root_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN'
if not os.path.exists(checkpoint_root_path):
    os.makedirs(checkpoint_root_path)
model_checkpoint_path = os.path.join(checkpoint_root_path, f'youtube_clickbait_simple_CNN_checkpoint' )

# %% [markdown]
# #Scripts

# %%
def read_tfrecord(example): 
    features = {
        "class": tf.io.FixedLenFeature([], tf.int64),   # shape [] means scalar
        "image": tf.io.FixedLenFeature([], tf.string),
        "label": tf.io.FixedLenFeature([], tf.string),  # one bytestring
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.reshape(image, [*TARGET_SIZE, 3])
    
    class_num = example['class']
    label  = example['label']
    return image, class_num, label

def load_dataset(filenames):
  option_no_order = tf.data.Options()
  option_no_order.experimental_deterministic = False

  dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
  dataset = dataset.with_options(option_no_order)
  dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTO)
  dataset = dataset.map(lambda image, class_num, label: (image, class_num))
  return dataset

def get_batched_dataset(dataset, train=False):
  dataset = dataset.cache()
  if train:
    dataset = dataset.shuffle(num_train_examples)
  dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
  dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
  return dataset

# %%
def create_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same", activation="relu")(inputs)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(64, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(128, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# #Read TFRecord data

# %%
read_YouTube_data = read_tfrec_data(tfrec_trainVal_files_path, VALIDATION_SPLIT=0.2, TESTING_SPLIT=0.0, MODE=0)

read_fvc_clickbait_data = read_tfrec_data(fvc_clickbait_tfrecFiles_path, VALIDATION_SPLIT=0.2, TESTING_SPLIT=0.0, MODE=0)

# splitting data files between training, validation and test
YouTube_filenames, YouTube_training_filenames, YouTube_validation_filenames, YouTube_testing_filenames = read_YouTube_data.get_tfrec_files()

fvc_filenames, fvc_training_filenames, fvc_validation_filenames, fvc_testing_filenames = read_fvc_clickbait_data.get_tfrec_files()


filenames = YouTube_filenames + fvc_filenames
training_filenames = YouTube_training_filenames + fvc_training_filenames
validation_filenames = YouTube_validation_filenames + fvc_validation_filenames

random.shuffle(filenames)
random.shuffle(training_filenames)
random.shuffle(validation_filenames)

print(f'Length FileNames : {len(filenames)} Length Training FileNames : {len(training_filenames)} Length Validation FileNames : {len(validation_filenames)}')

num_train_examples = 974 * len(YouTube_training_filenames) + 100 * len(fvc_training_filenames)
num_total_examples = 974 * len(YouTube_filenames) + 100 * len(fvc_filenames)

validation_steps = int(num_total_examples  // len(filenames) * len(validation_filenames)) // BATCH_SIZE
steps_per_epoch = int(num_total_examples  // len(filenames) * len(training_filenames)) // BATCH_SIZE


print("With a batch size of {}, there will be {} batches per training epoch and {} batch(es) per validation run.".format(BATCH_SIZE, steps_per_epoch, validation_steps))
# Out:
# Pattern matches 30 data files. Splitting dataset into 24 training files , 6 validation files and 0 test files
# Pattern matches 16 data files. Splitting dataset into 13 training files , 3 validation files and 0 test files
# Length FileNames : 46 Length Training FileNames : 37 Length Validation FileNames : 9
# With a batch size of 32, there will be 774 batches per training epoch and 188 batch(es) per validation run.

# %%
read_test_data = read_tfrec_data(tfrec_test_files_path, VALIDATION_SPLIT=0.0, TESTING_SPLIT=0.0, MODE=0) # Used only for testing
read_benchmark_data = read_tfrec_data(tfrec_benchmark_files_path, VALIDATION_SPLIT=0.0, TESTING_SPLIT=0.0, MODE=0) # Used only for benchmarking


testing_filenames, _, _,_ = read_test_data.get_tfrec_files()
benchmarking_filenames, _, _,_ = read_benchmark_data.get_tfrec_files()

len(testing_filenames), len(benchmarking_filenames)
# Out:
# Pattern matches 2 data files. Splitting dataset into 2 training files , 0 validation files and 0 test files
# Pattern matches 4 data files. Splitting dataset into 4 training files , 0 validation files and 0 test files
# (2, 4)

# %%
num_train_steps = steps_per_epoch * epochs
num_warmup_steps = num_train_steps // 10

# %% [markdown]
# #Load TFRecord into TF Dataset

# %%
# create the TF datasets
with tf.device('/cpu:0'):
  train_ds = load_dataset(training_filenames)
  val_ds = load_dataset(validation_filenames)
  test_ds = load_dataset(testing_filenames)
  benchmark_ds = load_dataset(benchmarking_filenames)

# %%
with tf.device('/cpu:0'):
  train_ds = get_batched_dataset(train_ds, train=True)
  val_ds = get_batched_dataset(val_ds)
  test_ds = get_batched_dataset(test_ds)
  benchmark_ds = get_batched_dataset(benchmark_ds)

# %%
for image, class_num in train_ds.take(1):
  for i in range(32):
    print(f"Image shape {image[i].shape}, Class={class_num[i]}, Label={CLASSES[class_num[i]]}")
# Out:
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=1, Label=clickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits
# Image shape (180, 180, 3), Class=0, Label=nonclickbaits

# %%
train_ds.element_spec, val_ds.element_spec, test_ds.element_spec, benchmark_ds.element_spec
# Out:
# ((TensorSpec(shape=(32, 180, 180, 3), dtype=tf.float32, name=None),
#   TensorSpec(shape=(32,), dtype=tf.int64, name=None)),
#  (TensorSpec(shape=(32, 180, 180, 3), dtype=tf.float32, name=None),
#   TensorSpec(shape=(32,), dtype=tf.int64, name=None)),
#  (TensorSpec(shape=(32, 180, 180, 3), dtype=tf.float32, name=None),
#   TensorSpec(shape=(32,), dtype=tf.int64, name=None)),
#  (TensorSpec(shape=(32, 180, 180, 3), dtype=tf.float32, name=None),
#   TensorSpec(shape=(32,), dtype=tf.int64, name=None)))

# %% [markdown]
# #Modeling

# %% [markdown]
# ##Build classifier

# %%
classifier_model = create_model(INPUT_SHAPE, NUM_CLASSES)
classifier_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 90, 90, 32)        896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 90, 90, 32)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 90, 90, 64)        256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 90, 90, 128)       73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 90, 90, 128)       512
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 94,273
# Trainable params: 93,825
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# #Train classifier model

# %% [markdown]
# ##Compile model

# %%
es = tf.keras.callbacks.EarlyStopping(
          monitor='val_loss', 
          verbose=1, 
          patience=5, 
          mode='min', 
          restore_best_weights=True
          )

mcb = tf.keras.callbacks.ModelCheckpoint (
         filepath=model_checkpoint_path,
         save_weights_only=True,
         monitor='val_loss',
         mode='min',
         verbose=1,
         save_best_only=True
        )

METRICS = [
             keras.metrics.TruePositives(name='tp'),
             keras.metrics.FalsePositives(name='fp'),
             keras.metrics.TrueNegatives(name='tn'),
             keras.metrics.FalseNegatives(name='fn'), 
             keras.metrics.BinaryAccuracy(name='accuracy'),
             keras.metrics.Precision(name='precision'),
             keras.metrics.Recall(name='recall'),
             keras.metrics.AUC(name='auc'),
             keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
          ]

#optimizer = optimization.create_optimizer(
#      init_lr=init_lr,
#      num_train_steps=num_train_steps,
#      num_warmup_steps=num_warmup_steps,
#      optimizer_type='adamw'
#      )

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    init_lr,
    decay_steps=num_train_steps,
    decay_rate=0.90,
    staircase=False)

optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr_schedule)

classifier_model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.BinaryCrossentropy(), 
    metrics=METRICS
    )

tf.keras.utils.plot_model(model=classifier_model, show_shapes=True, dpi=60)

# %% [markdown]
# ##Train

# %%
if os.path.exists(checkpoint_root_path) & len(os.listdir(checkpoint_root_path))>0:
  print('loading saved weight')
  classifier_model.load_weights(model_checkpoint_path)
else:
  print('No weight to initialize')
# Out:
# loading saved weight

# %%
history = classifier_model.fit(
             x=train_ds,
             validation_data=val_ds,
             epochs=epochs,
             callbacks=[es, mcb]
             )
# Out:
# Epoch 1/20
# 333/333 [==============================] - 52s 149ms/step - loss: 0.7123 - tp: 3036.0000 - fp: 2580.0000 - tn: 2761.0000 - fn: 2279.0000 - accuracy: 0.5440 - precision: 0.5406 - recall: 0.5712 - auc: 0.5570 - prc: 0.5367 - val_loss: 0.7366 - val_tp: 2774.0000 - val_fp: 3235.0000 - val_tn: 105.0000 - val_fn: 30.0000 - val_accuracy: 0.4686 - val_precision: 0.4616 - val_recall: 0.9893 - val_auc: 0.6107 - val_prc: 0.5282
#
# Epoch 00001: val_loss improved from inf to 0.73663, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 2/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6891 - tp: 3086.0000 - fp: 2369.0000 - tn: 2972.0000 - fn: 2229.0000 - accuracy: 0.5685 - precision: 0.5657 - recall: 0.5806 - auc: 0.5964 - prc: 0.5729 - val_loss: 0.6834 - val_tp: 2279.0000 - val_fp: 2097.0000 - val_tn: 1243.0000 - val_fn: 525.0000 - val_accuracy: 0.5732 - val_precision: 0.5208 - val_recall: 0.8128 - val_auc: 0.6361 - val_prc: 0.5541
#
# Epoch 00002: val_loss improved from 0.73663 to 0.68340, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 3/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6806 - tp: 3201.0000 - fp: 2398.0000 - tn: 2944.0000 - fn: 2113.0000 - accuracy: 0.5767 - precision: 0.5717 - recall: 0.6024 - auc: 0.6075 - prc: 0.5847 - val_loss: 0.6795 - val_tp: 2050.0000 - val_fp: 1865.0000 - val_tn: 1475.0000 - val_fn: 754.0000 - val_accuracy: 0.5737 - val_precision: 0.5236 - val_recall: 0.7311 - val_auc: 0.6330 - val_prc: 0.5666
#
# Epoch 00003: val_loss improved from 0.68340 to 0.67949, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 4/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6760 - tp: 3243.0000 - fp: 2353.0000 - tn: 2987.0000 - fn: 2073.0000 - accuracy: 0.5846 - precision: 0.5795 - recall: 0.6100 - auc: 0.6181 - prc: 0.5966 - val_loss: 0.6596 - val_tp: 1890.0000 - val_fp: 1510.0000 - val_tn: 1830.0000 - val_fn: 914.0000 - val_accuracy: 0.6055 - val_precision: 0.5559 - val_recall: 0.6740 - val_auc: 0.6552 - val_prc: 0.5788
#
# Epoch 00004: val_loss improved from 0.67949 to 0.65959, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 5/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6730 - tp: 3180.0000 - fp: 2284.0000 - tn: 3058.0000 - fn: 2134.0000 - accuracy: 0.5854 - precision: 0.5820 - recall: 0.5984 - auc: 0.6210 - prc: 0.6009 - val_loss: 0.6510 - val_tp: 1924.0000 - val_fp: 1448.0000 - val_tn: 1892.0000 - val_fn: 880.0000 - val_accuracy: 0.6211 - val_precision: 0.5706 - val_recall: 0.6862 - val_auc: 0.6753 - val_prc: 0.5999
#
# Epoch 00005: val_loss improved from 0.65959 to 0.65097, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 6/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6625 - tp: 3304.0000 - fp: 2190.0000 - tn: 3151.0000 - fn: 2011.0000 - accuracy: 0.6058 - precision: 0.6014 - recall: 0.6216 - auc: 0.6433 - prc: 0.6189 - val_loss: 0.6599 - val_tp: 1902.0000 - val_fp: 1352.0000 - val_tn: 1988.0000 - val_fn: 902.0000 - val_accuracy: 0.6331 - val_precision: 0.5845 - val_recall: 0.6783 - val_auc: 0.6799 - val_prc: 0.5996
#
# Epoch 00006: val_loss did not improve from 0.65097
# Epoch 7/20
# 333/333 [==============================] - 44s 132ms/step - loss: 0.6632 - tp: 3253.0000 - fp: 2222.0000 - tn: 3119.0000 - fn: 2062.0000 - accuracy: 0.5980 - precision: 0.5942 - recall: 0.6120 - auc: 0.6396 - prc: 0.6178 - val_loss: 0.6443 - val_tp: 1759.0000 - val_fp: 1233.0000 - val_tn: 2107.0000 - val_fn: 1045.0000 - val_accuracy: 0.6292 - val_precision: 0.5879 - val_recall: 0.6273 - val_auc: 0.6801 - val_prc: 0.6051
#
# Epoch 00007: val_loss improved from 0.65097 to 0.64427, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 8/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6562 - tp: 3378.0000 - fp: 2217.0000 - tn: 3123.0000 - fn: 1938.0000 - accuracy: 0.6101 - precision: 0.6038 - recall: 0.6354 - auc: 0.6533 - prc: 0.6306 - val_loss: 0.6698 - val_tp: 2193.0000 - val_fp: 1847.0000 - val_tn: 1493.0000 - val_fn: 611.0000 - val_accuracy: 0.5999 - val_precision: 0.5428 - val_recall: 0.7821 - val_auc: 0.6603 - val_prc: 0.5818
#
# Epoch 00008: val_loss did not improve from 0.64427
# Epoch 9/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6589 - tp: 3318.0000 - fp: 2126.0000 - tn: 3214.0000 - fn: 1998.0000 - accuracy: 0.6130 - precision: 0.6095 - recall: 0.6242 - auc: 0.6523 - prc: 0.6272 - val_loss: 0.6423 - val_tp: 1756.0000 - val_fp: 1144.0000 - val_tn: 2196.0000 - val_fn: 1048.0000 - val_accuracy: 0.6432 - val_precision: 0.6055 - val_recall: 0.6262 - val_auc: 0.6900 - val_prc: 0.6119
#
# Epoch 00009: val_loss improved from 0.64427 to 0.64232, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 10/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6539 - tp: 3339.0000 - fp: 2158.0000 - tn: 3183.0000 - fn: 1976.0000 - accuracy: 0.6120 - precision: 0.6074 - recall: 0.6282 - auc: 0.6605 - prc: 0.6386 - val_loss: 0.6413 - val_tp: 1643.0000 - val_fp: 1082.0000 - val_tn: 2258.0000 - val_fn: 1161.0000 - val_accuracy: 0.6349 - val_precision: 0.6029 - val_recall: 0.5859 - val_auc: 0.6843 - val_prc: 0.6081
#
# Epoch 00010: val_loss improved from 0.64232 to 0.64130, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 11/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6532 - tp: 3342.0000 - fp: 2123.0000 - tn: 3217.0000 - fn: 1974.0000 - accuracy: 0.6155 - precision: 0.6115 - recall: 0.6287 - auc: 0.6626 - prc: 0.6365 - val_loss: 0.6384 - val_tp: 1890.0000 - val_fp: 1279.0000 - val_tn: 2061.0000 - val_fn: 914.0000 - val_accuracy: 0.6431 - val_precision: 0.5964 - val_recall: 0.6740 - val_auc: 0.6948 - val_prc: 0.6140
#
# Epoch 00011: val_loss improved from 0.64130 to 0.63838, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 12/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6506 - tp: 3377.0000 - fp: 2058.0000 - tn: 3282.0000 - fn: 1939.0000 - accuracy: 0.6249 - precision: 0.6213 - recall: 0.6353 - auc: 0.6680 - prc: 0.6424 - val_loss: 0.6415 - val_tp: 1613.0000 - val_fp: 967.0000 - val_tn: 2373.0000 - val_fn: 1191.0000 - val_accuracy: 0.6488 - val_precision: 0.6252 - val_recall: 0.5752 - val_auc: 0.6965 - val_prc: 0.6189
#
# Epoch 00012: val_loss did not improve from 0.63838
# Epoch 13/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6456 - tp: 3360.0000 - fp: 2051.0000 - tn: 3289.0000 - fn: 1956.0000 - accuracy: 0.6240 - precision: 0.6210 - recall: 0.6321 - auc: 0.6736 - prc: 0.6516 - val_loss: 0.6558 - val_tp: 2175.0000 - val_fp: 1748.0000 - val_tn: 1592.0000 - val_fn: 629.0000 - val_accuracy: 0.6131 - val_precision: 0.5544 - val_recall: 0.7757 - val_auc: 0.6732 - val_prc: 0.5939
#
# Epoch 00013: val_loss did not improve from 0.63838
# Epoch 14/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6466 - tp: 3402.0000 - fp: 2079.0000 - tn: 3262.0000 - fn: 1913.0000 - accuracy: 0.6254 - precision: 0.6207 - recall: 0.6401 - auc: 0.6733 - prc: 0.6522 - val_loss: 0.6354 - val_tp: 2136.0000 - val_fp: 1507.0000 - val_tn: 1833.0000 - val_fn: 668.0000 - val_accuracy: 0.6460 - val_precision: 0.5863 - val_recall: 0.7618 - val_auc: 0.7077 - val_prc: 0.6354
#
# Epoch 00014: val_loss improved from 0.63838 to 0.63542, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 15/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6399 - tp: 3419.0000 - fp: 2043.0000 - tn: 3298.0000 - fn: 1896.0000 - accuracy: 0.6303 - precision: 0.6260 - recall: 0.6433 - auc: 0.6843 - prc: 0.6680 - val_loss: 0.6354 - val_tp: 1858.0000 - val_fp: 1146.0000 - val_tn: 2194.0000 - val_fn: 946.0000 - val_accuracy: 0.6595 - val_precision: 0.6185 - val_recall: 0.6626 - val_auc: 0.7092 - val_prc: 0.6392
#
# Epoch 00015: val_loss improved from 0.63542 to 0.63538, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 16/20
# 333/333 [==============================] - 44s 132ms/step - loss: 0.6365 - tp: 3479.0000 - fp: 2050.0000 - tn: 3292.0000 - fn: 1835.0000 - accuracy: 0.6354 - precision: 0.6292 - recall: 0.6547 - auc: 0.6881 - prc: 0.6713 - val_loss: 0.6417 - val_tp: 1685.0000 - val_fp: 1130.0000 - val_tn: 2210.0000 - val_fn: 1119.0000 - val_accuracy: 0.6340 - val_precision: 0.5986 - val_recall: 0.6009 - val_auc: 0.6846 - val_prc: 0.6131
#
# Epoch 00016: val_loss did not improve from 0.63538
# Epoch 17/20
# 333/333 [==============================] - 43s 131ms/step - loss: 0.6376 - tp: 3431.0000 - fp: 2013.0000 - tn: 3329.0000 - fn: 1883.0000 - accuracy: 0.6344 - precision: 0.6302 - recall: 0.6457 - auc: 0.6871 - prc: 0.6704 - val_loss: 0.6248 - val_tp: 1577.0000 - val_fp: 926.0000 - val_tn: 2414.0000 - val_fn: 1227.0000 - val_accuracy: 0.6496 - val_precision: 0.6300 - val_recall: 0.5624 - val_auc: 0.7075 - val_prc: 0.6392
#
# Epoch 00017: val_loss improved from 0.63538 to 0.62480, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_simple_CNN/youtube_clickbait_simple_CNN_checkpoint
# Epoch 18/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6333 - tp: 3493.0000 - fp: 1972.0000 - tn: 3369.0000 - fn: 1822.0000 - accuracy: 0.6440 - precision: 0.6392 - recall: 0.6572 - auc: 0.6953 - prc: 0.6753 - val_loss: 0.6287 - val_tp: 1680.0000 - val_fp: 936.0000 - val_tn: 2404.0000 - val_fn: 1124.0000 - val_accuracy: 0.6647 - val_precision: 0.6422 - val_recall: 0.5991 - val_auc: 0.7211 - val_prc: 0.6488
#
# Epoch 00018: val_loss did not improve from 0.62480
# Epoch 19/20
# 333/333 [==============================] - 44s 131ms/step - loss: 0.6324 - tp: 3498.0000 - fp: 2006.0000 - tn: 3335.0000 - fn: 1817.0000 - accuracy: 0.6412 - precision: 0.6355 - recall: 0.6581 - auc: 0.6927 - prc: 0.6772 - val_loss: 0.6576 - val_tp: 2346.0000 - val_fp: 1813.0000 - val_tn: 1527.0000 - val_fn: 458.0000 - val_accuracy: 0.6304 - val_precision: 0.5641 - val_recall: 0.8367 - val_auc: 0.7116 - val_prc: 0.6414
#
# Epoch 00019: val_loss did not improve from 0.62480
# Epoch 20/20
# 333/333 [==============================] - 43s 130ms/step - loss: 0.6329 - tp: 3470.0000 - fp: 1970.0000 - tn: 3370.0000 - fn: 1846.0000 - accuracy: 0.6419 - precision: 0.6379 - recall: 0.6527 - auc: 0.6945 - prc: 0.6766 - val_loss: 0.6536 - val_tp: 2351.0000 - val_fp: 1811.0000 - val_tn: 1529.0000 - val_fn: 453.0000 - val_accuracy: 0.6315 - val_precision: 0.5649 - val_recall: 0.8384 - val_auc: 0.7119 - val_prc: 0.6435
#
# Epoch 00020: val_loss did not improve from 0.62480

# %% [markdown]
# #Plot train history

# %%
vh.display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
vh.display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)

# %%
vh.display_training_curves(history.history['recall'], history.history['val_recall'], 'recall', 211)
vh.display_training_curves(history.history['precision'], history.history['val_precision'], 'precision', 212)

# %% [markdown]
# #Model Inference

# %% [markdown]
# ##Evaluate Classifier on Test set

# %%
results_test_set = classifier_model.evaluate(test_ds)

for name, value in zip(classifier_model.metrics_names, results_test_set):
  print(name, ': ', value)
print()
# Out:
# 60/60 [==============================] - 4s 56ms/step - loss: 0.6572 - tp: 740.0000 - fp: 556.0000 - tn: 466.0000 - fn: 158.0000 - accuracy: 0.6281 - precision: 0.5710 - recall: 0.8241 - auc: 0.7011 - prc: 0.6248
# loss :  0.6572341322898865
# tp :  740.0
# fp :  556.0
# tn :  466.0
# fn :  158.0
# accuracy :  0.628125011920929
# precision :  0.5709876418113708
# recall :  0.8240534663200378
# auc :  0.7011389136314392
# prc :  0.6248151659965515

# %%
test_image, y_true, y_pred, predicted_scores = mh.predict_on_test_vis(classifier_model,test_ds, BATCH_SIZE=BATCH_SIZE, N=30)
# Out:
# Accuracy: 0.621875
# Precision: 0.572543
# Recall: 0.804825
# F1 score: 0.669098
# ROC AUC: 0.630587
# [[230 274]
#  [ 89 367]]
# Non clickbaits Detected (True Negatives):  230
# Non-Clickbaits Detected as Clickbaits (False Positives):  274
# Clickbaits Detected as Non-clickbaits (False Negatives):  89
# Clickbaits Detected (True Positives):  367
# Total Non-clickbaits:  504
# Total Clickbaits:  456

# %% [markdown]
# ##Evaluate Classifier on Benchmarking set

# %%
results_benchmarking_set = classifier_model.evaluate(benchmark_ds)

for name, value in zip(classifier_model.metrics_names, results_benchmarking_set):
  print(name, ': ', value)
print()
# Out:
# 5/5 [==============================] - 3s 498ms/step - loss: 0.7024 - tp: 72.0000 - fp: 46.0000 - tn: 20.0000 - fn: 22.0000 - accuracy: 0.5750 - precision: 0.6102 - recall: 0.7660 - auc: 0.5949 - prc: 0.7206
# loss :  0.7023788094520569
# tp :  72.0
# fp :  46.0
# tn :  20.0
# fn :  22.0
# accuracy :  0.574999988079071
# precision :  0.6101694703102112
# recall :  0.7659574747085571
# auc :  0.5949388146400452
# prc :  0.7206291556358337

# %%
benchmark_image, y_true, y_pred, predicted_scores = mh.predict_on_test_vis(classifier_model,benchmark_ds, BATCH_SIZE=BATCH_SIZE, N=30)
# Out:
# Accuracy: 0.575000
# Precision: 0.610169
# Recall: 0.765957
# F1 score: 0.679245
# ROC AUC: 0.534494
# [[20 46]
#  [22 72]]
# Non clickbaits Detected (True Negatives):  20
# Non-Clickbaits Detected as Clickbaits (False Positives):  46
# Clickbaits Detected as Non-clickbaits (False Negatives):  22
# Clickbaits Detected (True Positives):  72
# Total Non-clickbaits:  66
# Total Clickbaits:  94
