# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul94jh/MSC-Research/blob/main/Seq_finetuning_YouTube_clickbait_all_rmsprop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup

# %% [markdown]
# Some good reads https://www.jeremyjordan.me/nn-learning-rate/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Check GPU, if assigned k8 then factory reset couple of times until we get Tesla GPU
# !nvidia-smi
# Out:
# Fri Jul 23 07:41:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -q tensorflow-text
# !pip install -q tf-models-official

# %% [markdown]
# #Imports

# %%
import os, math
import numpy as np
import pandas as pd
import requests
import shutil
import re
from pathlib import Path
import random
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score



import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from official.nlp.data import classifier_data_lib
from official.nlp.bert import tokenization
from official.nlp import optimization
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop


from tensorflow import keras
from official.nlp import optimization  # to create AdamW optmizer
AUTO = tf.data.experimental.AUTOTUNE # used in tf.data.Dataset API

tf.get_logger().setLevel('ERROR')

import sys

#Import custom script
sys.path.append('/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/scripts')
from tf_dataset_helpers import read_tfrec_data
import model_helpers as mh
import visualization_helpers as vh
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
print("TF Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# TF Version:  2.5.0
# Eager mode:  True
# Hub version:  0.12.0
# GPU is available

# %% [markdown]
# #Configs

# %% [markdown]
# ##General config

# %%
tfrec_trainVal_files_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/tfrec_data/train_val/'
tfrec_test_files_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/tfrec_data/test/'
stop_clickbait_tfrecFiles_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/Stop_clickbait/tfrec_data/'
fvc_clickbait_tfrecFiles_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/FVC_CORPUS/tfrec_data/'
tfrec_benchmark_files_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/invid_fake_video_v2/tfrec_data/'

model_root_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/saved_models'
saved_model_name = f'youtube_clickbait_finetuned_SEQ_all'
saved_model_path = os.path.join(model_root_path, saved_model_name )

checkpoint_root_path = '/content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all'
if not os.path.exists(checkpoint_root_path):
    os.makedirs(checkpoint_root_path)
model_checkpoint_path = os.path.join(checkpoint_root_path, f'youtube_clickbait_finetuned_SEQ_all_checkpoint' )

MAX_LEN = 128
VOCAB_SIZE = 20000
BATCH_SIZE = 64  
# Label categories
label_list = [0,1]

init_lr = 0.5e-1
end_lr = 1e-4
power = 2.0  
decay_rate=0.90


epochs = 30

# %% [markdown]
# #Scripts

# %%
#@title "Utilities [TF Dataset]"
def read_tfrecord(example):
    features = {
        "class": tf.io.FixedLenFeature([], tf.int64),   # shape [] means scalar
        "text": tf.io.FixedLenFeature([], tf.string),
        "label": tf.io.FixedLenFeature([], tf.string)  # one bytestring
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    
    
    class_num = example['class']
    text = example['text']
    label  = example['label']
    return text, class_num, label

def load_dataset(filenames):
  option_no_order = tf.data.Options()
  option_no_order.experimental_deterministic = False

  dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
  dataset = dataset.with_options(option_no_order)
  dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTO)
  return dataset

def get_batched_dataset(dataset, train=False):
  if train:
    dataset = dataset.shuffle(num_train_examples)
  dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
  dataset = dataset.cache().prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
  return dataset

# %%
#@title "Utilities [Create Model Definition]"
def create_model(encoder):
  inputs = keras.Input(shape=(None,), dtype="string")
  x = encoder(inputs)
  x = layers.Embedding(input_dim=len(encoder.get_vocabulary()), output_dim=128, mask_zero=True)(x)
  x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
  x = layers.Bidirectional(layers.LSTM(32))(x)
  x = layers.BatchNormalization()(x)
  x = layers.Dropout(0.2)(x)
  x = layers.Dense(64, activation='relu')(x)
  x = layers.Dropout(0.2)(x)
  outputs = layers.Dense(1, activation='sigmoid', name='classifier' )(x)
  model = keras.Model(inputs, outputs)
  return model

# %%
#@title "Utilities [Model prediction]"
def get_metrics(y_test, y_pred):
    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(y_test, y_pred)
    print('Accuracy: %f' % accuracy)
    # precision tp / (tp + fp)
    precision = precision_score(y_test, y_pred)
    print('Precision: %f' % precision)
    # recall: tp / (tp + fn)
    recall = recall_score(y_test, y_pred)
    print('Recall: %f' % recall)
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_test, y_pred)
    print('F1 score: %f' % f1)
    # ROC AUC
    auc = roc_auc_score(y_test, y_pred)
    print('ROC AUC: %f' % auc)
    # confusion matrix
    matrix = confusion_matrix(y_test, y_pred)
    print(matrix)

def predict_on_test_dataset(model, test_data, BATCH_SIZE=32):
  y_true=[]
  
  for text_feat, labels in test_data:
    for i in range(BATCH_SIZE):
      y_true.append(labels[i].numpy())


  predicted_scores  = model.predict(test_data)
  y_pred = (predicted_scores > 0.5).astype("int32")
  y_pred = y_pred.reshape(-1)
  get_metrics(y_true, y_pred)
  vh.plot_cm(y_true, predicted_scores)
  print()

# %%
#@title "Utilities [LR Callback & Metric]"
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer._decayed_lr(tf.float32) # I use ._decayed_lr method instead of .lr
    return lr

# Define the Required Callback Function
class printlearningrate(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        optimizer = self.model.optimizer
        lr = K.eval(optimizer.lr)
        Epoch_count = epoch + 1
        print('\n', "Epoch:", Epoch_count, ', LR', (lr(tf.float32)))

# %% [markdown]
# #Read TFRecord data

# %%
#@title  "Load files & Split into Train and Val"

# read tfrec files from disk storage
read_YouTube_data = read_tfrec_data(tfrec_trainVal_files_path, VALIDATION_SPLIT=0.2, TESTING_SPLIT=0.0, MODE=1)

read_stop_clickbait_data = read_tfrec_data(stop_clickbait_tfrecFiles_path, VALIDATION_SPLIT=0.2, TESTING_SPLIT=0.0, MODE=1)

read_fvc_clickbait_data = read_tfrec_data(fvc_clickbait_tfrecFiles_path, VALIDATION_SPLIT=0.2, TESTING_SPLIT=0.0, MODE=1)

# splitting data files between training, validation and test
YouTube_filenames, YouTube_training_filenames, YouTube_validation_filenames, YouTube_testing_filenames = read_YouTube_data.get_tfrec_files()

stop_clickbait_filenames, stop_clickbait_training_filenames,stop_clickbait_validation_filenames, stop_clickbait_testing_filenames = read_stop_clickbait_data.get_tfrec_files()

fvc_filenames, fvc_training_filenames, fvc_validation_filenames, fvc_testing_filenames = read_fvc_clickbait_data.get_tfrec_files()


filenames = YouTube_filenames + stop_clickbait_filenames + fvc_filenames
training_filenames = YouTube_training_filenames + stop_clickbait_training_filenames + fvc_training_filenames
validation_filenames = YouTube_validation_filenames + stop_clickbait_validation_filenames + fvc_validation_filenames

random.shuffle(filenames)
random.shuffle(training_filenames)
random.shuffle(validation_filenames)

print(f'Length FileNames : {len(filenames)} Length Training FileNames : {len(training_filenames)} Length Validation FileNames : {len(validation_filenames)}')

num_train_examples = 974 * len(YouTube_training_filenames) + 500 * len(stop_clickbait_training_filenames) + 100 * len(fvc_training_filenames)
num_total_examples = 974 * len(YouTube_filenames) + 500 * len(stop_clickbait_filenames) + 100 * len(fvc_filenames)

validation_steps = int(num_total_examples  // len(filenames) * len(validation_filenames)) // BATCH_SIZE
steps_per_epoch = int(num_total_examples  // len(filenames) * len(training_filenames)) // BATCH_SIZE

num_train_steps = steps_per_epoch * epochs
num_warmup_steps = num_train_steps // 10

print("With a batch size of {}, there will be {} batches per training epoch and {} batch(es) per validation run.".format(BATCH_SIZE, steps_per_epoch, validation_steps))
# Out:
# Pattern matches 14 data files. Splitting dataset into 12 training files , 2 validation files and 0 test files
# Pattern matches 64 data files. Splitting dataset into 52 training files , 12 validation files and 0 test files
# Pattern matches 16 data files. Splitting dataset into 13 training files , 3 validation files and 0 test files
# Length FileNames : 94 Length Training FileNames : 77 Length Validation FileNames : 17
# With a batch size of 64, there will be 603 batches per training epoch and 133 batch(es) per validation run.

# %%
#@title  "Load Test and Benchmarking files"
read_test_data = read_tfrec_data(tfrec_test_files_path, VALIDATION_SPLIT=0.0, TESTING_SPLIT=0.0, MODE=1) # Used only for testing
read_benchmark_data = read_tfrec_data(tfrec_benchmark_files_path, VALIDATION_SPLIT=0.0, TESTING_SPLIT=0.0, MODE=1) # Used only for benchmarking


testing_filenames, _, _,_ = read_test_data.get_tfrec_files()
benchmarking_filenames, _, _,_ = read_benchmark_data.get_tfrec_files()

len(testing_filenames), len(benchmarking_filenames)
# Out:
# Pattern matches 2 data files. Splitting dataset into 2 training files , 0 validation files and 0 test files
# Pattern matches 4 data files. Splitting dataset into 4 training files , 0 validation files and 0 test files
# (2, 4)

# %% [markdown]
# #Load TFRecord into TF Dataset

# %%
# create the TF datasets
with tf.device('/cpu:0'):
  train_ds = load_dataset(training_filenames)
  val_ds = load_dataset(validation_filenames)
  test_ds = load_dataset(testing_filenames)
  benchmark_ds = load_dataset(benchmarking_filenames)

# %%
for i,(text, class_num, label) in enumerate(train_ds.take(2)):
  print(f"text : {text.numpy()}, class : {class_num.numpy()}, label : {label.numpy()}")
# Out:
# text : b'replacing our furniture with the foam pit like the video for more foam pit vids so we actually replaced our whole living room furniture with the foam cubes how do my parents allow this anything for you guys haha i seriously enjoy building and creating things with the foam pit so if you have more video ideas to make with them let me know thanks so much for watching please share and subscribe if you re new love you all subscribe for daily content official rug apparel add me on snapchat thefazerug follow me on my social media to stay connected twitter instagram snapchat thefazerug add me to see how i live my daily life d if you read this far down the description i love you', class : 1, label : b'clickbaits'
# text : b'rainbow science and why headphones get so tangled links optic science of rainbows wiki article flying through rainbow first video flying through rainbow second video petrichor the smell of rain why do wires knot so easily scientific paper on random knotting of an agitated string also music courtuesy of jake chudnow like us on facebook twitter tweetsauce', class : 0, label : b'nonclickbaits'

# %%
for i,(text, class_num, label) in enumerate(test_ds.take(2)):
  print(f"text : {text.numpy()}, class : {class_num.numpy()}, label : {label.numpy()}")
# Out:
# text : b'cruel bombs command and control book follow michael stevens music by and general info about nuclear weapons and testing nevada nuclear test footage amazing channel with hd restored historical nuclear footage edgerton detonation photos amazing shot of nuclear weapon test notice it occured nearly past the horizon shot from nagasaki north carolina incident nuclear boyscout documentary kokura spared feynman text hiroshima bonsai nuclear effects isotopes put into atmosphere by nuclear testing have allowed historians to detect art forgeries the flag of bikini atoll has an interesting story', class : 0, label : b'nonclickbaits'
# text : b'failing to follow up the fault in our stars in which john green discusses the years since the publication of his novel the fault in our stars why there hasn t been a new book yet and why he has returned to writing after some time away thanks to hank for beginning this discussion with his great video last week subscribe to our newsletter and join the community at help transcribe videos john s twitter john s tumblr hank s twitter hank s tumblr', class : 0, label : b'nonclickbaits'

# %%
for i,(text, class_num, label) in enumerate(benchmark_ds.take(2)):
  print(f"text : {text.numpy()}, class : {class_num.numpy()}, label : {label.numpy()}")
# Out:
# text : b'white tiger kills man who fell into its enclosure at delhi zoo a white tiger attacked and killed a young man who apparently slipped and fell into its enclosure at the delhi zoo on tuesday disturbing images not suitable for children watch more videos', class : 0, label : b'nonclickbaits'
# text : b'muslims push a car down a subway stairs at the metro in brussels and burn the christmas tree happy new year', class : 1, label : b'clickbaits'

# %%
# We need only Text and numeric Label from the dataset
with tf.device('/cpu:0'):
  train_ds = train_ds.map(lambda text, class_num, label:(text, class_num))
  val_ds = val_ds.map(lambda text, class_num, label:(text, class_num))
  test_ds = test_ds.map(lambda text, class_num, label:(text, class_num))
  benchmark_ds = benchmark_ds.map(lambda text, class_num, label:(text, class_num))

# %%
# Create text encoder and adapt it on train dataset
encoder = tf.keras.layers.experimental.preprocessing.TextVectorization(
    max_tokens=VOCAB_SIZE, output_sequence_length=MAX_LEN)
encoder.adapt(train_ds.map(lambda text, label: text))

# %%
#Let's see the first 20 vocabulary
vocab = np.array(encoder.get_vocabulary())
vocab[:20]
# Out:
# array(['', '[UNK]', 'the', 'to', 'and', 'a', 'of', 'on', 'in', 'you',
#        'for', 's', 'my', 'twitter', 'is', 'i', 'follow', 'that', 'this',
#        'more'], dtype='<U24')

# %%
train_ds.element_spec, val_ds.element_spec, test_ds.element_spec, benchmark_ds.element_spec
# Out:
# ((TensorSpec(shape=(), dtype=tf.string, name=None),
#   TensorSpec(shape=(), dtype=tf.int64, name=None)),
#  (TensorSpec(shape=(), dtype=tf.string, name=None),
#   TensorSpec(shape=(), dtype=tf.int64, name=None)),
#  (TensorSpec(shape=(), dtype=tf.string, name=None),
#   TensorSpec(shape=(), dtype=tf.int64, name=None)),
#  (TensorSpec(shape=(), dtype=tf.string, name=None),
#   TensorSpec(shape=(), dtype=tf.int64, name=None)))

# %%
with tf.device('/cpu:0'):
  train_ds = get_batched_dataset(train_ds, train=True)
  val_ds = get_batched_dataset(val_ds)
  test_ds = get_batched_dataset(test_ds)
  benchmark_ds = get_batched_dataset(benchmark_ds)

# %% [markdown]
# #Modeling

# %% [markdown]
# ##Build classifier

# %%
classifier_model = create_model(encoder)
classifier_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# text_vectorization (TextVect (None, 128)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 128, 128)          2560000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128, 128)          98816
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 64)                41216
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# classifier (Dense)           (None, 1)                 65
# =================================================================
# Total params: 2,704,513
# Trainable params: 2,704,385
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# ##Train classifier model

# %% [markdown]
# ###Compile model

# %%
es_callback = tf.keras.callbacks.EarlyStopping(
          monitor='val_loss', 
          verbose=1, 
          patience=10, 
          mode='min', 
          restore_best_weights=True
          )

mck_callback = tf.keras.callbacks.ModelCheckpoint (
         filepath=model_checkpoint_path,
         save_weights_only=True,
         monitor='val_loss',
         mode='min',
         verbose=1,
         save_best_only=True
        )

lr_callback = printlearningrate() 

#optimizer = optimization.create_optimizer(
#      init_lr=init_lr,
#      num_train_steps=num_train_steps,
#      num_warmup_steps=num_warmup_steps,
#      optimizer_type='adamw'
#      )


lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate = init_lr,
    decay_steps=num_train_steps,
    end_learning_rate=end_lr,
    power=power,
)

#lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#    init_lr,
#    decay_steps=num_train_steps,
#    decay_rate=decay_rate)

optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr_schedule)
lr_metric = get_lr_metric(optimizer)


METRICS = [
             keras.metrics.TruePositives(name='tp'),
             keras.metrics.FalsePositives(name='fp'),
             keras.metrics.TrueNegatives(name='tn'),
             keras.metrics.FalseNegatives(name='fn'), 
             keras.metrics.BinaryAccuracy(name='accuracy'),
             keras.metrics.Precision(name='precision'),
             keras.metrics.Recall(name='recall'),
             keras.metrics.AUC(name='auc', curve='ROC'),
             keras.metrics.AUC(name='prc', curve='PR'), 
             keras.metrics.PrecisionAtRecall(recall=0.95, name='pr_at_recall'),
             keras.metrics.SensitivityAtSpecificity(specificity=0.95,name='ss_at_sp'),
             lr_metric,
          ]


classifier_model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.BinaryCrossentropy(), 
    metrics=METRICS
    )

tf.keras.utils.plot_model(model=classifier_model, show_shapes=True, dpi=60)

# %% [markdown]
# ###Train

# %%
#@title Load weights if available
#if os.path.exists(model_checkpoint_path):
#  print('loading saved weight')
#  classifier_model.load_weights(model_checkpoint_path)
#else:
#  print('No weight to initialize')

# %%
history = classifier_model.fit(
             x=train_ds,
             validation_data=val_ds,
             epochs=epochs,
             callbacks=[es_callback, mck_callback]
             )
# Out:
# Epoch 1/30
# 608/608 [==============================] - 115s 157ms/step - loss: 0.3167 - tp: 16357.0000 - fp: 1528.0000 - tn: 18245.0000 - fn: 2782.0000 - accuracy: 0.8892 - precision: 0.9146 - recall: 0.8546 - auc: 0.9489 - prc: 0.9464 - pr_at_recall: 0.7784 - ss_at_sp: 0.7970 - lr: 0.0483 - val_loss: 0.5052 - val_tp: 3861.0000 - val_fp: 810.0000 - val_tn: 3400.0000 - val_fn: 121.0000 - val_accuracy: 0.8864 - val_precision: 0.8266 - val_recall: 0.9696 - val_auc: 0.9671 - val_prc: 0.9539 - val_pr_at_recall: 0.8845 - val_ss_at_sp: 0.8882 - val_lr: 0.0467
#
# Epoch 00001: val_loss improved from inf to 0.50520, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 2/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.2550 - tp: 17154.0000 - fp: 1392.0000 - tn: 18381.0000 - fn: 1985.0000 - accuracy: 0.9132 - precision: 0.9249 - recall: 0.8963 - auc: 0.9659 - prc: 0.9638 - pr_at_recall: 0.8584 - ss_at_sp: 0.8603 - lr: 0.0451 - val_loss: 0.4128 - val_tp: 3870.0000 - val_fp: 932.0000 - val_tn: 3278.0000 - val_fn: 112.0000 - val_accuracy: 0.8726 - val_precision: 0.8059 - val_recall: 0.9719 - val_auc: 0.9701 - val_prc: 0.9619 - val_pr_at_recall: 0.8715 - val_ss_at_sp: 0.8837 - val_lr: 0.0435
#
# Epoch 00002: val_loss improved from 0.50520 to 0.41276, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 3/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.2700 - tp: 17173.0000 - fp: 1609.0000 - tn: 18164.0000 - fn: 1966.0000 - accuracy: 0.9081 - precision: 0.9143 - recall: 0.8973 - auc: 0.9624 - prc: 0.9590 - pr_at_recall: 0.8438 - ss_at_sp: 0.8391 - lr: 0.0420 - val_loss: 0.3591 - val_tp: 3798.0000 - val_fp: 705.0000 - val_tn: 3505.0000 - val_fn: 184.0000 - val_accuracy: 0.8915 - val_precision: 0.8434 - val_recall: 0.9538 - val_auc: 0.9667 - val_prc: 0.9568 - val_pr_at_recall: 0.8500 - val_ss_at_sp: 0.8614 - val_lr: 0.0404
#
# Epoch 00003: val_loss improved from 0.41276 to 0.35912, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 4/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2698 - tp: 16998.0000 - fp: 1488.0000 - tn: 18285.0000 - fn: 2141.0000 - accuracy: 0.9067 - precision: 0.9195 - recall: 0.8881 - auc: 0.9625 - prc: 0.9584 - pr_at_recall: 0.8398 - ss_at_sp: 0.8397 - lr: 0.0390 - val_loss: 0.3651 - val_tp: 3757.0000 - val_fp: 605.0000 - val_tn: 3605.0000 - val_fn: 225.0000 - val_accuracy: 0.8987 - val_precision: 0.8613 - val_recall: 0.9435 - val_auc: 0.9660 - val_prc: 0.9553 - val_pr_at_recall: 0.8478 - val_ss_at_sp: 0.8717 - val_lr: 0.0375
#
# Epoch 00004: val_loss did not improve from 0.35912
# Epoch 5/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2681 - tp: 16963.0000 - fp: 1428.0000 - tn: 18345.0000 - fn: 2176.0000 - accuracy: 0.9074 - precision: 0.9224 - recall: 0.8863 - auc: 0.9624 - prc: 0.9588 - pr_at_recall: 0.8391 - ss_at_sp: 0.8428 - lr: 0.0360 - val_loss: 0.3486 - val_tp: 3804.0000 - val_fp: 748.0000 - val_tn: 3462.0000 - val_fn: 178.0000 - val_accuracy: 0.8870 - val_precision: 0.8357 - val_recall: 0.9553 - val_auc: 0.9650 - val_prc: 0.9564 - val_pr_at_recall: 0.8452 - val_ss_at_sp: 0.8664 - val_lr: 0.0346
#
# Epoch 00005: val_loss improved from 0.35912 to 0.34862, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 6/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2736 - tp: 16712.0000 - fp: 1444.0000 - tn: 18329.0000 - fn: 2427.0000 - accuracy: 0.9005 - precision: 0.9205 - recall: 0.8732 - auc: 0.9592 - prc: 0.9580 - pr_at_recall: 0.8222 - ss_at_sp: 0.8284 - lr: 0.0333 - val_loss: 0.2865 - val_tp: 3524.0000 - val_fp: 312.0000 - val_tn: 3898.0000 - val_fn: 458.0000 - val_accuracy: 0.9060 - val_precision: 0.9187 - val_recall: 0.8850 - val_auc: 0.9639 - val_prc: 0.9622 - val_pr_at_recall: 0.8314 - val_ss_at_sp: 0.8315 - val_lr: 0.0319
#
# Epoch 00006: val_loss improved from 0.34862 to 0.28646, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 7/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2800 - tp: 16978.0000 - fp: 1575.0000 - tn: 18198.0000 - fn: 2161.0000 - accuracy: 0.9040 - precision: 0.9151 - recall: 0.8871 - auc: 0.9580 - prc: 0.9542 - pr_at_recall: 0.8243 - ss_at_sp: 0.8214 - lr: 0.0306 - val_loss: 0.3827 - val_tp: 3663.0000 - val_fp: 521.0000 - val_tn: 3689.0000 - val_fn: 319.0000 - val_accuracy: 0.8975 - val_precision: 0.8755 - val_recall: 0.9199 - val_auc: 0.9605 - val_prc: 0.9527 - val_pr_at_recall: 0.8147 - val_ss_at_sp: 0.8285 - val_lr: 0.0293
#
# Epoch 00007: val_loss did not improve from 0.28646
# Epoch 8/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2839 - tp: 17064.0000 - fp: 1797.0000 - tn: 17976.0000 - fn: 2075.0000 - accuracy: 0.9005 - precision: 0.9047 - recall: 0.8916 - auc: 0.9562 - prc: 0.9495 - pr_at_recall: 0.8258 - ss_at_sp: 0.8030 - lr: 0.0280 - val_loss: 0.3015 - val_tp: 3622.0000 - val_fp: 475.0000 - val_tn: 3735.0000 - val_fn: 360.0000 - val_accuracy: 0.8981 - val_precision: 0.8841 - val_recall: 0.9096 - val_auc: 0.9612 - val_prc: 0.9581 - val_pr_at_recall: 0.8145 - val_ss_at_sp: 0.8119 - val_lr: 0.0268
#
# Epoch 00008: val_loss did not improve from 0.28646
# Epoch 9/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2815 - tp: 17047.0000 - fp: 1904.0000 - tn: 17869.0000 - fn: 2092.0000 - accuracy: 0.8973 - precision: 0.8995 - recall: 0.8907 - auc: 0.9563 - prc: 0.9504 - pr_at_recall: 0.8250 - ss_at_sp: 0.7865 - lr: 0.0256 - val_loss: 0.3278 - val_tp: 3691.0000 - val_fp: 648.0000 - val_tn: 3562.0000 - val_fn: 291.0000 - val_accuracy: 0.8854 - val_precision: 0.8507 - val_recall: 0.9269 - val_auc: 0.9559 - val_prc: 0.9452 - val_pr_at_recall: 0.8223 - val_ss_at_sp: 0.7825 - val_lr: 0.0244
#
# Epoch 00009: val_loss did not improve from 0.28646
# Epoch 10/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2796 - tp: 17243.0000 - fp: 2109.0000 - tn: 17664.0000 - fn: 1896.0000 - accuracy: 0.8971 - precision: 0.8910 - recall: 0.9009 - auc: 0.9566 - prc: 0.9491 - pr_at_recall: 0.8327 - ss_at_sp: 0.7814 - lr: 0.0232 - val_loss: 0.2960 - val_tp: 3752.0000 - val_fp: 706.0000 - val_tn: 3504.0000 - val_fn: 230.0000 - val_accuracy: 0.8857 - val_precision: 0.8416 - val_recall: 0.9422 - val_auc: 0.9589 - val_prc: 0.9521 - val_pr_at_recall: 0.8291 - val_ss_at_sp: 0.8184 - val_lr: 0.0221
#
# Epoch 00010: val_loss did not improve from 0.28646
# Epoch 11/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2789 - tp: 17294.0000 - fp: 2129.0000 - tn: 17644.0000 - fn: 1845.0000 - accuracy: 0.8979 - precision: 0.8904 - recall: 0.9036 - auc: 0.9562 - prc: 0.9505 - pr_at_recall: 0.8244 - ss_at_sp: 0.7896 - lr: 0.0210 - val_loss: 0.3153 - val_tp: 3686.0000 - val_fp: 639.0000 - val_tn: 3571.0000 - val_fn: 296.0000 - val_accuracy: 0.8859 - val_precision: 0.8523 - val_recall: 0.9257 - val_auc: 0.9561 - val_prc: 0.9506 - val_pr_at_recall: 0.8113 - val_ss_at_sp: 0.7941 - val_lr: 0.0199
#
# Epoch 00011: val_loss did not improve from 0.28646
# Epoch 12/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2748 - tp: 17301.0000 - fp: 2116.0000 - tn: 17657.0000 - fn: 1838.0000 - accuracy: 0.8984 - precision: 0.8910 - recall: 0.9040 - auc: 0.9570 - prc: 0.9499 - pr_at_recall: 0.8320 - ss_at_sp: 0.7778 - lr: 0.0189 - val_loss: 0.2951 - val_tp: 3743.0000 - val_fp: 704.0000 - val_tn: 3506.0000 - val_fn: 239.0000 - val_accuracy: 0.8849 - val_precision: 0.8417 - val_recall: 0.9400 - val_auc: 0.9606 - val_prc: 0.9546 - val_pr_at_recall: 0.8241 - val_ss_at_sp: 0.8001 - val_lr: 0.0179
#
# Epoch 00012: val_loss did not improve from 0.28646
# Epoch 13/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2689 - tp: 17370.0000 - fp: 2143.0000 - tn: 17630.0000 - fn: 1769.0000 - accuracy: 0.8995 - precision: 0.8902 - recall: 0.9076 - auc: 0.9587 - prc: 0.9524 - pr_at_recall: 0.8337 - ss_at_sp: 0.7909 - lr: 0.0169 - val_loss: 0.2850 - val_tp: 3750.0000 - val_fp: 748.0000 - val_tn: 3462.0000 - val_fn: 232.0000 - val_accuracy: 0.8804 - val_precision: 0.8337 - val_recall: 0.9417 - val_auc: 0.9603 - val_prc: 0.9571 - val_pr_at_recall: 0.8215 - val_ss_at_sp: 0.7983 - val_lr: 0.0159
#
# Epoch 00013: val_loss improved from 0.28646 to 0.28498, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 14/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2597 - tp: 17335.0000 - fp: 2036.0000 - tn: 17737.0000 - fn: 1804.0000 - accuracy: 0.9013 - precision: 0.8949 - recall: 0.9057 - auc: 0.9608 - prc: 0.9557 - pr_at_recall: 0.8414 - ss_at_sp: 0.7988 - lr: 0.0150 - val_loss: 0.2871 - val_tp: 3728.0000 - val_fp: 673.0000 - val_tn: 3537.0000 - val_fn: 254.0000 - val_accuracy: 0.8868 - val_precision: 0.8471 - val_recall: 0.9362 - val_auc: 0.9607 - val_prc: 0.9551 - val_pr_at_recall: 0.8175 - val_ss_at_sp: 0.8039 - val_lr: 0.0141
#
# Epoch 00014: val_loss did not improve from 0.28498
# Epoch 15/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2457 - tp: 17348.0000 - fp: 1887.0000 - tn: 17886.0000 - fn: 1791.0000 - accuracy: 0.9055 - precision: 0.9019 - recall: 0.9064 - auc: 0.9647 - prc: 0.9612 - pr_at_recall: 0.8452 - ss_at_sp: 0.8251 - lr: 0.0132 - val_loss: 0.2771 - val_tp: 3710.0000 - val_fp: 618.0000 - val_tn: 3592.0000 - val_fn: 272.0000 - val_accuracy: 0.8914 - val_precision: 0.8572 - val_recall: 0.9317 - val_auc: 0.9627 - val_prc: 0.9573 - val_pr_at_recall: 0.8336 - val_ss_at_sp: 0.8209 - val_lr: 0.0124
#
# Epoch 00015: val_loss improved from 0.28498 to 0.27707, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 16/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2389 - tp: 17457.0000 - fp: 1840.0000 - tn: 17933.0000 - fn: 1682.0000 - accuracy: 0.9095 - precision: 0.9046 - recall: 0.9121 - auc: 0.9667 - prc: 0.9632 - pr_at_recall: 0.8567 - ss_at_sp: 0.8322 - lr: 0.0116 - val_loss: 0.2958 - val_tp: 3709.0000 - val_fp: 650.0000 - val_tn: 3560.0000 - val_fn: 273.0000 - val_accuracy: 0.8873 - val_precision: 0.8509 - val_recall: 0.9314 - val_auc: 0.9616 - val_prc: 0.9549 - val_pr_at_recall: 0.8239 - val_ss_at_sp: 0.8076 - val_lr: 0.0108
#
# Epoch 00016: val_loss did not improve from 0.27707
# Epoch 17/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.2349 - tp: 17455.0000 - fp: 1724.0000 - tn: 18049.0000 - fn: 1684.0000 - accuracy: 0.9124 - precision: 0.9101 - recall: 0.9120 - auc: 0.9674 - prc: 0.9636 - pr_at_recall: 0.8588 - ss_at_sp: 0.8466 - lr: 0.0100 - val_loss: 0.2698 - val_tp: 3679.0000 - val_fp: 537.0000 - val_tn: 3673.0000 - val_fn: 303.0000 - val_accuracy: 0.8975 - val_precision: 0.8726 - val_recall: 0.9239 - val_auc: 0.9624 - val_prc: 0.9568 - val_pr_at_recall: 0.8307 - val_ss_at_sp: 0.8174 - val_lr: 0.0093
#
# Epoch 00017: val_loss improved from 0.27707 to 0.26983, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 18/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.2318 - tp: 17406.0000 - fp: 1720.0000 - tn: 18053.0000 - fn: 1733.0000 - accuracy: 0.9113 - precision: 0.9101 - recall: 0.9095 - auc: 0.9684 - prc: 0.9654 - pr_at_recall: 0.8627 - ss_at_sp: 0.8498 - lr: 0.0086 - val_loss: 0.2588 - val_tp: 3699.0000 - val_fp: 570.0000 - val_tn: 3640.0000 - val_fn: 283.0000 - val_accuracy: 0.8959 - val_precision: 0.8665 - val_recall: 0.9289 - val_auc: 0.9641 - val_prc: 0.9603 - val_pr_at_recall: 0.8348 - val_ss_at_sp: 0.8290 - val_lr: 0.0079
#
# Epoch 00018: val_loss improved from 0.26983 to 0.25882, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 19/30
# 608/608 [==============================] - 90s 147ms/step - loss: 0.2226 - tp: 17533.0000 - fp: 1660.0000 - tn: 18113.0000 - fn: 1606.0000 - accuracy: 0.9161 - precision: 0.9135 - recall: 0.9161 - auc: 0.9706 - prc: 0.9675 - pr_at_recall: 0.8715 - ss_at_sp: 0.8608 - lr: 0.0072 - val_loss: 0.2619 - val_tp: 3667.0000 - val_fp: 491.0000 - val_tn: 3719.0000 - val_fn: 315.0000 - val_accuracy: 0.9016 - val_precision: 0.8819 - val_recall: 0.9209 - val_auc: 0.9648 - val_prc: 0.9585 - val_pr_at_recall: 0.8387 - val_ss_at_sp: 0.8317 - val_lr: 0.0066
#
# Epoch 00019: val_loss did not improve from 0.25882
# Epoch 20/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.2150 - tp: 17541.0000 - fp: 1529.0000 - tn: 18244.0000 - fn: 1598.0000 - accuracy: 0.9196 - precision: 0.9198 - recall: 0.9165 - auc: 0.9723 - prc: 0.9692 - pr_at_recall: 0.8814 - ss_at_sp: 0.8724 - lr: 0.0060 - val_loss: 0.2416 - val_tp: 3624.0000 - val_fp: 423.0000 - val_tn: 3787.0000 - val_fn: 358.0000 - val_accuracy: 0.9047 - val_precision: 0.8955 - val_recall: 0.9101 - val_auc: 0.9655 - val_prc: 0.9630 - val_pr_at_recall: 0.8337 - val_ss_at_sp: 0.8358 - val_lr: 0.0055
#
# Epoch 00020: val_loss improved from 0.25882 to 0.24159, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 21/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.2046 - tp: 17649.0000 - fp: 1499.0000 - tn: 18274.0000 - fn: 1490.0000 - accuracy: 0.9232 - precision: 0.9217 - recall: 0.9221 - auc: 0.9749 - prc: 0.9725 - pr_at_recall: 0.8853 - ss_at_sp: 0.8802 - lr: 0.0049 - val_loss: 0.2438 - val_tp: 3621.0000 - val_fp: 403.0000 - val_tn: 3807.0000 - val_fn: 361.0000 - val_accuracy: 0.9067 - val_precision: 0.8999 - val_recall: 0.9093 - val_auc: 0.9660 - val_prc: 0.9611 - val_pr_at_recall: 0.8417 - val_ss_at_sp: 0.8483 - val_lr: 0.0044
#
# Epoch 00021: val_loss did not improve from 0.24159
# Epoch 22/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.1946 - tp: 17736.0000 - fp: 1432.0000 - tn: 18341.0000 - fn: 1403.0000 - accuracy: 0.9271 - precision: 0.9253 - recall: 0.9267 - auc: 0.9769 - prc: 0.9750 - pr_at_recall: 0.8963 - ss_at_sp: 0.8924 - lr: 0.0039 - val_loss: 0.2410 - val_tp: 3603.0000 - val_fp: 378.0000 - val_tn: 3832.0000 - val_fn: 379.0000 - val_accuracy: 0.9076 - val_precision: 0.9050 - val_recall: 0.9048 - val_auc: 0.9659 - val_prc: 0.9626 - val_pr_at_recall: 0.8291 - val_ss_at_sp: 0.8423 - val_lr: 0.0035
#
# Epoch 00022: val_loss improved from 0.24159 to 0.24101, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 23/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.1845 - tp: 17824.0000 - fp: 1339.0000 - tn: 18434.0000 - fn: 1315.0000 - accuracy: 0.9318 - precision: 0.9301 - recall: 0.9313 - auc: 0.9790 - prc: 0.9769 - pr_at_recall: 0.9089 - ss_at_sp: 0.9098 - lr: 0.0031 - val_loss: 0.2363 - val_tp: 3623.0000 - val_fp: 368.0000 - val_tn: 3842.0000 - val_fn: 359.0000 - val_accuracy: 0.9113 - val_precision: 0.9078 - val_recall: 0.9098 - val_auc: 0.9671 - val_prc: 0.9639 - val_pr_at_recall: 0.8409 - val_ss_at_sp: 0.8531 - val_lr: 0.0027
#
# Epoch 00023: val_loss improved from 0.24101 to 0.23634, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 24/30
# 608/608 [==============================] - 89s 146ms/step - loss: 0.1747 - tp: 17868.0000 - fp: 1265.0000 - tn: 18508.0000 - fn: 1271.0000 - accuracy: 0.9348 - precision: 0.9339 - recall: 0.9336 - auc: 0.9810 - prc: 0.9796 - pr_at_recall: 0.9173 - ss_at_sp: 0.9136 - lr: 0.0023 - val_loss: 0.2377 - val_tp: 3606.0000 - val_fp: 369.0000 - val_tn: 3841.0000 - val_fn: 376.0000 - val_accuracy: 0.9091 - val_precision: 0.9072 - val_recall: 0.9056 - val_auc: 0.9670 - val_prc: 0.9632 - val_pr_at_recall: 0.8435 - val_ss_at_sp: 0.8498 - val_lr: 0.0020
#
# Epoch 00024: val_loss did not improve from 0.23634
# Epoch 25/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.1685 - tp: 17919.0000 - fp: 1274.0000 - tn: 18499.0000 - fn: 1220.0000 - accuracy: 0.9359 - precision: 0.9336 - recall: 0.9363 - auc: 0.9824 - prc: 0.9807 - pr_at_recall: 0.9180 - ss_at_sp: 0.9185 - lr: 0.0017 - val_loss: 0.2359 - val_tp: 3597.0000 - val_fp: 351.0000 - val_tn: 3859.0000 - val_fn: 385.0000 - val_accuracy: 0.9102 - val_precision: 0.9111 - val_recall: 0.9033 - val_auc: 0.9676 - val_prc: 0.9647 - val_pr_at_recall: 0.8445 - val_ss_at_sp: 0.8503 - val_lr: 0.0014
#
# Epoch 00025: val_loss improved from 0.23634 to 0.23586, saving model to /content/drive/MyDrive/Colab Notebooks/clcikbait_detection/dataset/YouTube_clickbait/checkpoints/youtube_clickbait_finetuned_SEQ_all/youtube_clickbait_finetuned_SEQ_all_checkpoint
# Epoch 26/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.1561 - tp: 18037.0000 - fp: 1128.0000 - tn: 18645.0000 - fn: 1102.0000 - accuracy: 0.9427 - precision: 0.9411 - recall: 0.9424 - auc: 0.9846 - prc: 0.9835 - pr_at_recall: 0.9325 - ss_at_sp: 0.9329 - lr: 0.0011 - val_loss: 0.2367 - val_tp: 3577.0000 - val_fp: 327.0000 - val_tn: 3883.0000 - val_fn: 405.0000 - val_accuracy: 0.9106 - val_precision: 0.9162 - val_recall: 0.8983 - val_auc: 0.9676 - val_prc: 0.9635 - val_pr_at_recall: 0.8496 - val_ss_at_sp: 0.8511 - val_lr: 8.9406e-04
#
# Epoch 00026: val_loss did not improve from 0.23586
# Epoch 27/30
# 608/608 [==============================] - 90s 147ms/step - loss: 0.1462 - tp: 18066.0000 - fp: 1035.0000 - tn: 18738.0000 - fn: 1073.0000 - accuracy: 0.9458 - precision: 0.9458 - recall: 0.9439 - auc: 0.9865 - prc: 0.9855 - pr_at_recall: 0.9394 - ss_at_sp: 0.9405 - lr: 7.0099e-04 - val_loss: 0.2457 - val_tp: 3574.0000 - val_fp: 332.0000 - val_tn: 3878.0000 - val_fn: 408.0000 - val_accuracy: 0.9097 - val_precision: 0.9150 - val_recall: 0.8975 - val_auc: 0.9667 - val_prc: 0.9630 - val_pr_at_recall: 0.8475 - val_ss_at_sp: 0.8584 - val_lr: 5.2730e-04
#
# Epoch 00027: val_loss did not improve from 0.23586
# Epoch 28/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.1397 - tp: 18144.0000 - fp: 1006.0000 - tn: 18767.0000 - fn: 995.0000 - accuracy: 0.9486 - precision: 0.9475 - recall: 0.9480 - auc: 0.9875 - prc: 0.9865 - pr_at_recall: 0.9450 - ss_at_sp: 0.9467 - lr: 3.9068e-04 - val_loss: 0.2477 - val_tp: 3580.0000 - val_fp: 342.0000 - val_tn: 3868.0000 - val_fn: 402.0000 - val_accuracy: 0.9092 - val_precision: 0.9128 - val_recall: 0.8990 - val_auc: 0.9668 - val_prc: 0.9631 - val_pr_at_recall: 0.8493 - val_ss_at_sp: 0.8594 - val_lr: 2.7328e-04
#
# Epoch 00028: val_loss did not improve from 0.23586
# Epoch 29/30
# 608/608 [==============================] - 90s 147ms/step - loss: 0.1307 - tp: 18189.0000 - fp: 964.0000 - tn: 18809.0000 - fn: 950.0000 - accuracy: 0.9508 - precision: 0.9497 - recall: 0.9504 - auc: 0.9889 - prc: 0.9882 - pr_at_recall: 0.9490 - ss_at_sp: 0.9510 - lr: 1.9312e-04 - val_loss: 0.2513 - val_tp: 3563.0000 - val_fp: 330.0000 - val_tn: 3880.0000 - val_fn: 419.0000 - val_accuracy: 0.9086 - val_precision: 0.9152 - val_recall: 0.8948 - val_auc: 0.9668 - val_prc: 0.9629 - val_pr_at_recall: 0.8565 - val_ss_at_sp: 0.8584 - val_lr: 1.3199e-04
#
# Epoch 00029: val_loss did not improve from 0.23586
# Epoch 30/30
# 608/608 [==============================] - 89s 147ms/step - loss: 0.1273 - tp: 18225.0000 - fp: 937.0000 - tn: 18836.0000 - fn: 914.0000 - accuracy: 0.9524 - precision: 0.9511 - recall: 0.9522 - auc: 0.9896 - prc: 0.9890 - pr_at_recall: 0.9528 - ss_at_sp: 0.9542 - lr: 1.0801e-04 - val_loss: 0.2508 - val_tp: 3572.0000 - val_fp: 332.0000 - val_tn: 3878.0000 - val_fn: 410.0000 - val_accuracy: 0.9094 - val_precision: 0.9150 - val_recall: 0.8970 - val_auc: 0.9670 - val_prc: 0.9632 - val_pr_at_recall: 0.8534 - val_ss_at_sp: 0.8604 - val_lr: 1.0000e-04
#
# Epoch 00030: val_loss did not improve from 0.23586

# %%
# Save model weights
#classifier_model.save_weights(model_checkpoint_path)

# %% [markdown]
# #Plot train history

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
lr =  history.history['lr']
plt.plot(lr, loss_train, 'g', label='Training loss')
plt.plot(lr, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Learning rate')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
vh.display_training_curves(history.history['lr'], history.history['val_lr'], 'learning rate decay', 211)

# %%
vh.display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
vh.display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)

# %%
vh.display_training_curves(history.history['recall'], history.history['val_recall'], 'recall', 211)
vh.display_training_curves(history.history['precision'], history.history['val_precision'], 'precision', 212)

# %%
vh.display_training_curves(history.history['auc'], history.history['val_auc'], 'auc-roc', 211)
vh.display_training_curves(history.history['prc'], history.history['val_prc'], 'auc-prc', 212)

# %%
vh.display_training_curves(history.history['pr_at_recall'], history.history['val_pr_at_recall'], 'precision at recall', 211)
vh.display_training_curves(history.history['ss_at_sp'], history.history['val_ss_at_sp'], 'sensitivity at specificity', 212)

# %% [markdown]
# # Model Inference
# We have trained the classifier, now let's use the trained model to infer the test dataset. Beside the test dataset, we also have benchmark dataset that we would also to see the eefectiveness of our model over benchmark dataset on predicting the clickbait's.

# %% [markdown]
# ##Model Evaluation

# %% [markdown]
# ###Evaluate Classifier on Test set

# %%
results_test_set = classifier_model.evaluate(test_ds)

for name, value in zip(classifier_model.metrics_names, results_test_set):
  print(name, ': ', value)
print()
# Out:
# 30/30 [==============================] - 2s 65ms/step - loss: 0.2412 - tp: 834.0000 - fp: 102.0000 - tn: 921.0000 - fn: 63.0000 - accuracy: 0.9141 - precision: 0.8910 - recall: 0.9298 - auc: 0.9709 - prc: 0.9691 - pr_at_recall: 0.8282 - ss_at_sp: 0.8863 - lr: 1.0000e-04
# loss :  0.24124887585639954
# tp :  834.0
# fp :  102.0
# tn :  921.0
# fn :  63.0
# accuracy :  0.9140625
# precision :  0.8910256624221802
# recall :  0.9297658801078796
# auc :  0.9708957076072693
# prc :  0.9691066741943359
# pr_at_recall :  0.8281553387641907
# ss_at_sp :  0.8862876296043396
# lr :  9.999999747378752e-05

# %% [markdown]
# ### Evaluate Classifier on Benchmarking set

# %%
results_benchmarking_set = classifier_model.evaluate(benchmark_ds)

for name, value in zip(classifier_model.metrics_names, results_benchmarking_set):
  print(name, ': ', value)
print()
# Out:
# 2/2 [==============================] - 0s 75ms/step - loss: 1.1382 - tp: 40.0000 - fp: 4.0000 - tn: 49.0000 - fn: 35.0000 - accuracy: 0.6953 - precision: 0.9091 - recall: 0.5333 - auc: 0.8262 - prc: 0.8563 - pr_at_recall: 0.5859 - ss_at_sp: 0.4000 - lr: 1.0000e-04
# loss :  1.138221025466919
# tp :  40.0
# fp :  4.0
# tn :  49.0
# fn :  35.0
# accuracy :  0.6953125
# precision :  0.9090909361839294
# recall :  0.5333333611488342
# auc :  0.8261633515357971
# prc :  0.8562740683555603
# pr_at_recall :  0.5859375
# ss_at_sp :  0.4000000059604645
# lr :  9.999999747378752e-05

# %% [markdown]
# ##Export Model for inference

# %%
#classifier_model.save(saved_model_path, include_optimizer=False)

# %% [markdown]
# ##Model prediction

# %%
#saved_classifier = keras.models.load_model(saved_model_path)

# %% [markdown]
# ### Prediction for Test set

# %%
predict_on_test_dataset(classifier_model, test_ds, BATCH_SIZE=BATCH_SIZE)
# Out:
# Accuracy: 0.914062
# Precision: 0.891026
# Recall: 0.929766
# F1 score: 0.909984
# ROC AUC: 0.915030
# [[921 102]
#  [ 63 834]]
# Non clickbaits Detected (True Negatives):  921
# Non-Clickbaits Detected as Clickbaits (False Positives):  102
# Clickbaits Detected as Non-clickbaits (False Negatives):  63
# Clickbaits Detected (True Positives):  834
# Total Non-clickbaits:  1023
# Total Clickbaits:  897

# %% [markdown]
# ### Prediction for Benchmarking set

# %%
predict_on_test_dataset(classifier_model, benchmark_ds, BATCH_SIZE=BATCH_SIZE)
# Out:
# Accuracy: 0.695312
# Precision: 0.909091
# Recall: 0.533333
# F1 score: 0.672269
# ROC AUC: 0.728931
# [[49  4]
#  [35 40]]
# Non clickbaits Detected (True Negatives):  49
# Non-Clickbaits Detected as Clickbaits (False Positives):  4
# Clickbaits Detected as Non-clickbaits (False Negatives):  35
# Clickbaits Detected (True Positives):  40
# Total Non-clickbaits:  53
# Total Clickbaits:  75
